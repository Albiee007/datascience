# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read the csv file into a pandas Dataframe

# %%
df = pd.read_csv('C:/Users/ashly/Documents/DataScience/ShareMarket/options-nifty/data/raw-data/nifty-50-hist/1990-2023j-une.csv')

# %% [markdown]
# ### Explore the data by checking the DataFrame structure and basic statistics:

# %%
print(df.head())  # Display the first few rows of the DataFrame
print(df.info())  # Get information about the DataFrame
print(df.describe())  # Generate summary statistics of the DataFrame
# Out:
#           Date      Open      High       Low     Close
# 0  30 Jun 2023  19076.85  19201.70  19024.60  19189.05
# 1  28 Jun 2023  18908.15  19011.25  18861.35  18972.10
# 2  27 Jun 2023  18748.55  18829.25  18714.25  18817.40
# 3  26 Jun 2023  18682.35  18722.05  18646.70  18691.20
# 4  23 Jun 2023  18741.85  18756.40  18647.10  18665.50
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8006 entries, 0 to 8005
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    8006 non-null   object
#  1   Open    6881 non-null   float64
#  2   High    6881 non-null   float64
#  3   Low     6881 non-null   float64
#  4   Close   8006 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 312.9+ KB
# None
#                Open          High           Low         Close
# count   6881.000000   6881.000000   6881.000000   8006.000000
# mean    5788.674456   5824.989259   5744.216160   5088.808825
# std     4853.203504   4871.376352   4824.865719   4815.667771
# min      786.370000    805.820000    775.430000    279.020000
# 25%     1359.800000   1377.250000   1345.050000   1100.400000
# 50%     4942.700000   4994.350000   4897.600000   3646.000000
# 75%     8542.800000   8594.800000   8503.450000   7978.600000
# max    19076.850000  19201.700000  19024.600000  19189.050000

# %% [markdown]
# ### Prepare the data for visualization:

# %%
date = pd.to_datetime(df['Date'])  # Convert the 'Date' column to datetime format
open_prices = df['Open']
close_prices = df['Close']

# %% [markdown]
# ### Create a line plot to visualize the open and closing prices over time:

# %%
plt.figure(figsize=(12, 6))
plt.plot(date, open_prices, label='Open Price')
plt.plot(date, close_prices, label='Close Price')
plt.title('Nifty 50 Open and Close Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
